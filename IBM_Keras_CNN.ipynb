# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Flatten

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %%
def cnn():
  model=Sequential()

  model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model=cnn()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=1)
scores=model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 [==============================] - 16s 51ms/step - loss: 0.2836 - accuracy: 0.9200 - val_loss: 0.0988 - val_accuracy: 0.9721
# Epoch 2/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0837 - accuracy: 0.9758 - val_loss: 0.0601 - val_accuracy: 0.9819
# Epoch 3/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0573 - accuracy: 0.9836 - val_loss: 0.0511 - val_accuracy: 0.9834
# Epoch 4/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0443 - accuracy: 0.9869 - val_loss: 0.0433 - val_accuracy: 0.9852
# Epoch 5/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0364 - accuracy: 0.9892 - val_loss: 0.0407 - val_accuracy: 0.9860
# Epoch 6/10
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.0395 - val_accuracy: 0.9872
# Epoch 7/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0345 - val_accuracy: 0.9884
# Epoch 8/10
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0206 - accuracy: 0.9939 - val_loss: 0.0378 - val_accuracy: 0.9874
# Epoch 9/10
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.0384 - val_accuracy: 0.9872
# Epoch 10/10
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 0.0395 - val_accuracy: 0.9865
# Accuracy: 0.9865000247955322
#  Error: 1.3499975204467773

# %%
def cnn2():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %%
# build the model
model = cnn2()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=1)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 [==============================] - 17s 56ms/step - loss: 0.5093 - accuracy: 0.8540 - val_loss: 0.1412 - val_accuracy: 0.9587
# Epoch 2/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.1216 - accuracy: 0.9640 - val_loss: 0.0813 - val_accuracy: 0.9737
# Epoch 3/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0849 - accuracy: 0.9743 - val_loss: 0.0674 - val_accuracy: 0.9799
# Epoch 4/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0672 - accuracy: 0.9801 - val_loss: 0.0598 - val_accuracy: 0.9808
# Epoch 5/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0580 - accuracy: 0.9824 - val_loss: 0.0456 - val_accuracy: 0.9858
# Epoch 6/10
# 300/300 [==============================] - 16s 55ms/step - loss: 0.0489 - accuracy: 0.9852 - val_loss: 0.0517 - val_accuracy: 0.9835
# Epoch 7/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0430 - accuracy: 0.9872 - val_loss: 0.0463 - val_accuracy: 0.9844
# Epoch 8/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0389 - accuracy: 0.9882 - val_loss: 0.0360 - val_accuracy: 0.9878
# Epoch 9/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0337 - accuracy: 0.9900 - val_loss: 0.0417 - val_accuracy: 0.9865
# Epoch 10/10
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.0385 - val_accuracy: 0.9868
# Accuracy: 0.9868000149726868
#  Error: 1.3199985027313232
